# %%
import xml.etree.ElementTree as ET
import re

# %%
tree_words = ET.parse('words/ES2002d.A.words.xml')
root_words = tree_words.getroot()

tree_act = ET.parse('dialogueActs/ES2002d.A.dialog-act.xml')
root_act = tree_act.getroot()

tree_roles = ET.parse('participantRoles/ES2002d.A.role.xml')
root_roles = tree_roles.getroot()

root_act.find('dact').find("child",{"items": "nite"})
nsmap = {'nite':'http://nite.sourceforge.net/'}
root_act.getchildren()[0].find('nite:child',nsmap).attrib['href']
root_words.find('w[@nite:id="ES2002d.A.words1"]',nsmap).attrib
# Out:
# {'{http://nite.sourceforge.net/}id': 'ES2002d.A.words1',
#  'starttime': '59.39',
#  'endtime': '59.39',
#  'punc': 'true'}

# %%
def parse_times(string):
    start_re = "\#id\((.*?)\)" 
    stop_re =  "\.\.id\((.*)\)"
    
    start = re.search(start_re,string).groups(0)[0]
    if re.search(stop_re,string):
        stop = re.search(stop_re,string).groups(0)[0]
    else:
        stop = start
    return {'start': start, 'stop': stop}

def get_role(time,root_roles):
    for role in root_roles.getchildren():
        if(role.attrib['endtime'] > time):
            return role.attrib['type']
            

dataset = []
meetings = {}

meeting_ids = ['ES2002d','ES2008b','ES2008d','ES2009d','IS1003d']
participant_ids = ['A','B','C','D']

for meeting_id in meeting_ids:
    meetings[meeting_id] = []
    for participant_id in participant_ids:
        root_act = ET.parse('dialogueActs/{}.{}.dialog-act.xml'.format(meeting_id,participant_id)).getroot()
        root_roles = ET.parse('participantRoles/{}.{}.role.xml'.format(meeting_id,participant_id)).getroot()
        root_words = ET.parse('words/{}.{}.words.xml'.format(meeting_id,participant_id)).getroot()
        for act in root_act.getchildren():
            markers = parse_times(act.find('nite:child',nsmap).attrib['href'])
            starttime = root_words.find('*[@nite:id="{}"]'.format(markers['start']),nsmap).attrib['starttime']
            endtime = root_words.find('*[@nite:id="{}"]'.format(markers['stop']),nsmap).attrib['endtime']
            meetings[meeting_id].append({'participant': participant_id, 'starttime': starttime, 'endtime': endtime, 'role': get_role(endtime,root_roles) })

# %%
class Meeting:
    
    def __init__(self,meet):
        meeting = []
        for part in meet:
            meeting.append({"start_time": part['starttime'], "stop_time": part['endtime'], "participant": part['participant'], "role": part['role']})
        self.meeting = meeting
    
    def participations(self,p_id):
        return list(filter(lambda item: item['participant'] == p_id, self.meeting))
    
    def participations_by_role(self,p_id,role):
        return list(filter(lambda item: item['participant'] == p_id and item['role'] == role, self.meeting))
    
    def participations_not_by_role(self,p_id,role):
        return list(filter(lambda item: item['participant'] == p_id and item['role'] != role, self.meeting))
        
    def participations_count(self,p_id):
        return len(self.participations(p_id))
    
    def participation_time(self,p_id):
        time = []
        parts = self.participations(p_id)
        for part in parts:
            time.append(float(part['stop_time']) - float(part['start_time']))
        return time
    
    def protagonic_participation_time(self,p_id):
        time = 0
        parts = self.participations_by_role(p_id,"Protagonist")
        for part in parts:
            time += (float(part['stop_time']) - float(part['start_time']))
        return time
    
    def protagonic_participation_time_prc(self,p_id):
        return 100 * (self.protagonic_participation_time(p_id) / float(self.participations(p_id)[-1]["stop_time"]))
    
    def protagonism_prc(self,p_id):
        return 100 * (len(self.participations_by_role(p_id,"Protagonist")) / len(self.participations(p_id)))
    
    def not_protagonism_prc(self,p_id):
        return 100 * (len(self.participations_not_by_role(p_id,"Protagonist")) / len(self.participations(p_id)))

# %%
Meeting(meetings['ES2002d']).meeting
# Out:
# [{'start_time': '59.26',
#   'stop_time': '59.39',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '71.75',
#   'stop_time': '74.016',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '101.92',
#   'stop_time': '106.23',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '106.39',
#   'stop_time': '111.34',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '112.76',
#   'stop_time': '115.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '115.76',
#   'stop_time': '116.422',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '118.1',
#   'stop_time': '121.31',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '121.31',
#   'stop_time': '128.26',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '128.26',
#   'stop_time': '128.91',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '128.91',
#   'stop_time': '131.63',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '131.63',
#   'stop_time': '136.6',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '137.92',
#   'stop_time': '146.65',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '148.82',
#   'stop_time': '149.72',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '154.18',
#   'stop_time': '156.34',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '156.34',
#   'stop_time': '156.79',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '158.4',
#   'stop_time': '159.66',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '159.66',
#   'stop_time': '162.78',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '164.2',
#   'stop_time': '165.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '165.69',
#   'stop_time': '167.22',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '167.22',
#   'stop_time': '169.25',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '170.71',
#   'stop_time': '171.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '171.69',
#   'stop_time': '173.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '173.76',
#   'stop_time': '176.85',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '190.39',
#   'stop_time': '190.7',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '190.7',
#   'stop_time': '193.18',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '193.18',
#   'stop_time': '199.37',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '199.37',
#   'stop_time': '201.96',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '202.92',
#   'stop_time': '205.35',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '205.35',
#   'stop_time': '206.43',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '209.73',
#   'stop_time': '210.43',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '211.12',
#   'stop_time': '211.71',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '255.955',
#   'stop_time': '259.83',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '259.89',
#   'stop_time': '260.12',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '268.09',
#   'stop_time': '271.232',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '274.02',
#   'stop_time': '276.91',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '279.14',
#   'stop_time': '279.9',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '279.9',
#   'stop_time': '281.15',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '281.15',
#   'stop_time': '282.33',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '285.93',
#   'stop_time': '287.92',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '335.83',
#   'stop_time': '339.16',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '339.16',
#   'stop_time': '341.61',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '342.9',
#   'stop_time': '343.98',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '345.08',
#   'stop_time': '345.42',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '345.42',
#   'stop_time': '346.37',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '346.37',
#   'stop_time': '349.36',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '350.88',
#   'stop_time': '351.33',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '353.06',
#   'stop_time': '353.63',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '353.63',
#   'stop_time': '354.99',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '354.99',
#   'stop_time': '359.87',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '365.19',
#   'stop_time': '370.05',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '371.3',
#   'stop_time': '371.9',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '373.4',
#   'stop_time': '374.32',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '374.32',
#   'stop_time': '375.63',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '375.63',
#   'stop_time': '378.4',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '378.4',
#   'stop_time': '383.6',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '383.6',
#   'stop_time': '388.33',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '389.74',
#   'stop_time': '389.96',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '421.58',
#   'stop_time': '422.14',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '424.42',
#   'stop_time': '424.78',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '426.39',
#   'stop_time': '426.87',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '430.48',
#   'stop_time': '431.448',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '432.42',
#   'stop_time': '432.75',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '433.96',
#   'stop_time': '435.94',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '435.94',
#   'stop_time': '437.87',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '437.87',
#   'stop_time': '439.79',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '439.79',
#   'stop_time': '440.48',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '446.55',
#   'stop_time': '446.86',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '456.85',
#   'stop_time': '457.2',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '458.07',
#   'stop_time': '458.32',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '461.72',
#   'stop_time': '462.32',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '466.19',
#   'stop_time': '467.65',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '468.84',
#   'stop_time': '469.78',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '471.53',
#   'stop_time': '471.75',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '475.97',
#   'stop_time': '479.28',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '480.56',
#   'stop_time': '483.12',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '485.65',
#   'stop_time': '486.08',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '487.22',
#   'stop_time': '489.59',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '493.68',
#   'stop_time': '494.336',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '498.69',
#   'stop_time': '499.9',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '513.03',
#   'stop_time': '516.02',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '517.76',
#   'stop_time': '519.32',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '519.32',
#   'stop_time': '522.75',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '528.82',
#   'stop_time': '532.14',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '534.09',
#   'stop_time': '536.65',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '541.33',
#   'stop_time': '541.77',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '543.48',
#   'stop_time': '544.41',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '544.41',
#   'stop_time': '544.59',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '548.256',
#   'stop_time': '549.658',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '579.67',
#   'stop_time': '581.33',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '581.33',
#   'stop_time': '582.78',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '582.78',
#   'stop_time': '588.29',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '588.29',
#   'stop_time': '589.43',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '590.86',
#   'stop_time': '594.57',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '594.57',
#   'stop_time': '597.16',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '597.16',
#   'stop_time': '599.53',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '599.53',
#   'stop_time': '603.3',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '603.3',
#   'stop_time': '605.506',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '607.237',
#   'stop_time': '608.459',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '610.5',
#   'stop_time': '610.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '612.69',
#   'stop_time': '614.31',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '616.6',
#   'stop_time': '617.1',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '618.46',
#   'stop_time': '618.75',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '622.12',
#   'stop_time': '624.215',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '631.76',
#   'stop_time': '634.74',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '638.2',
#   'stop_time': '639.87',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '639.87',
#   'stop_time': '641.44',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '642.98',
#   'stop_time': '643.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '643.69',
#   'stop_time': '646.37',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '646.37',
#   'stop_time': '648.93',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '653.07',
#   'stop_time': '663.49',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '668.08',
#   'stop_time': '671.32',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '671.32',
#   'stop_time': '674.57',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '676.45',
#   'stop_time': '677.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '682.2',
#   'stop_time': '683.62',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '683.62',
#   'stop_time': '684.18',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '684.18',
#   'stop_time': '686.08',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '688.13',
#   'stop_time': '689.79',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '692.39',
#   'stop_time': '694.55',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '694.55',
#   'stop_time': '697.81',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '697.81',
#   'stop_time': '700.16',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '724.36',
#   'stop_time': '724.62',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '736.049',
#   'stop_time': '737.529',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '762.26',
#   'stop_time': '763.45',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '765.62',
#   'stop_time': '765.87',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '772.42',
#   'stop_time': '776.592',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '777.91',
#   'stop_time': '781.18',
#   'participant': 'A',
#   'role': 'Protagonist'},
#  {'start_time': '781.18',
#   'stop_time': '782.69',
#   'participant': 'A',
#   'role': 'Protagonist'},
#  {'start_time': '782.69',
#   'stop_time': '783.5',
#   'participant': 'A',
#   'role': 'Protagonist'},
#  {'start_time': '785.24',
#   'stop_time': '785.44',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '792.36',
#   'stop_time': '792.62',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '804.4',
#   'stop_time': '804.57',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '809.38',
#   'stop_time': '810.86',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '812.92',
#   'stop_time': '814.458',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '816.92',
#   'stop_time': '817.4',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '866.32',
#   'stop_time': '869.54',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '869.54',
#   'stop_time': '873.07',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '873.07',
#   'stop_time': '875.9',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '875.9',
#   'stop_time': '879.73',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '879.73',
#   'stop_time': '882.314',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '883.33',
#   'stop_time': '883.48',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '883.48',
#   'stop_time': '888.52',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '888.52',
#   'stop_time': '893.52',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '895.12',
#   'stop_time': '895.66',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '932.13',
#   'stop_time': '934.47',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '954.85',
#   'stop_time': '956.23',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '956.23',
#   'stop_time': '956.688',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '957.89',
#   'stop_time': '958.78',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '960.1',
#   'stop_time': '962.48',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '962.48',
#   'stop_time': '962.79',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '962.79',
#   'stop_time': '964.96',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '970.96',
#   'stop_time': '972.29',
#   'participant': 'A',
#   'role': 'Protagonist'},
#  {'start_time': '976.06',
#   'stop_time': '977.7',
#   'participant': 'A',
#   'role': 'Protagonist'},
#  {'start_time': '1052.71',
#   'stop_time': '1053.72',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1077.06',
#   'stop_time': '1078.09',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1081.56',
#   'stop_time': '1083.06',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1088.36',
#   'stop_time': '1088.53',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1088.53',
#   'stop_time': '1090.15',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1095.65',
#   'stop_time': '1096.13',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1096.13',
#   'stop_time': '1096.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1101.52',
#   'stop_time': '1102.408',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1111.14',
#   'stop_time': '1111.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1112.86',
#   'stop_time': '1113.57',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1113.57',
#   'stop_time': '1117.83',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1117.83',
#   'stop_time': '1118.05',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1121.938',
#   'stop_time': '1122.529',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1126.03',
#   'stop_time': '1126.46',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1127.75',
#   'stop_time': '1131.5',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1131.5',
#   'stop_time': '1133.42',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1133.42',
#   'stop_time': '1134.816',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1137.41',
#   'stop_time': '1137.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1137.69',
#   'stop_time': '1139.8',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1139.8',
#   'stop_time': '1141.94',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1158.52',
#   'stop_time': '1159.69',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1181.6',
#   'stop_time': '1182.03',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1182.03',
#   'stop_time': '1182.73',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1186.78',
#   'stop_time': '1189.77',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1189.77',
#   'stop_time': '1190.0',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1192.47',
#   'stop_time': '1192.85',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1275.696',
#   'stop_time': '1277.504',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1308.21',
#   'stop_time': '1308.35',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1349.83',
#   'stop_time': '1350.75',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1360.78',
#   'stop_time': '1361.56',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1361.56',
#   'stop_time': '1366.16',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1367.38',
#   'stop_time': '1370.576',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1387.48',
#   'stop_time': '1388.77',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1388.77',
#   'stop_time': '1394.56',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1427.712',
#   'stop_time': '1431.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1568.64',
#   'stop_time': '1571.7',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1571.7',
#   'stop_time': '1574.8',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1574.8',
#   'stop_time': '1576.25',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1593.79',
#   'stop_time': '1594.01',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1596.28',
#   'stop_time': '1601.17',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1601.17',
#   'stop_time': '1606.2',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1606.2',
#   'stop_time': '1615.66',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1615.91',
#   'stop_time': '1622.06',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1622.06',
#   'stop_time': '1625.33',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1625.33',
#   'stop_time': '1629.65',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1629.65',
#   'stop_time': '1635.12',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1635.12',
#   'stop_time': '1640.59',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1642.63',
#   'stop_time': '1643.7',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1643.7',
#   'stop_time': '1644.82',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1644.82',
#   'stop_time': '1646.84',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1646.84',
#   'stop_time': '1647.16',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1647.16',
#   'stop_time': '1649.77',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1649.77',
#   'stop_time': '1653.264',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1658.96',
#   'stop_time': '1660.294',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1662.784',
#   'stop_time': '1664.4',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1678.416',
#   'stop_time': '1680.52',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1692.608',
#   'stop_time': '1694.688',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1731.008',
#   'stop_time': '1731.872',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1734.72',
#   'stop_time': '1736.6',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1736.6',
#   'stop_time': '1738.7',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1738.7',
#   'stop_time': '1745.9',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1745.9',
#   'stop_time': '1752.21',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1752.21',
#   'stop_time': '1757.61',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1757.61',
#   'stop_time': '1763.952',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1781.91',
#   'stop_time': '1786.62',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1786.62',
#   'stop_time': '1791.78',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1791.78',
#   'stop_time': '1795.7',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1798.19',
#   'stop_time': '1798.35',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1799.73',
#   'stop_time': '1800.08',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1813.99',
#   'stop_time': '1820.36',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1820.36',
#   'stop_time': '1823.45',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1823.45',
#   'stop_time': '1825.08',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1850.51',
#   'stop_time': '1852.26',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1886.5',
#   'stop_time': '1887.2',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '1972.11',
#   'stop_time': '1977.25',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1977.25',
#   'stop_time': '1982.76',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1982.76',
#   'stop_time': '1987.85',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1987.85',
#   'stop_time': '1991.07',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '1991.07',
#   'stop_time': '1992.539',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2011.38',
#   'stop_time': '2014.32',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2014.32',
#   'stop_time': '2016.98',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2016.98',
#   'stop_time': '2023.83',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2023.83',
#   'stop_time': '2024.79',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2024.79',
#   'stop_time': '2026.9',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2026.9',
#   'stop_time': '2028.19',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2032.592',
#   'stop_time': '2036.81',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2036.81',
#   'stop_time': '2039.328',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2043.48',
#   'stop_time': '2046.51',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2046.51',
#   'stop_time': '2049.62',
#   'participant': 'A',
#   'role': 'Supporter'},
#  {'start_time': '2066.76',
#   'stop_time': '2068.72',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2068.72',
#   'stop_time': '2069.79',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2069.79',
#   'stop_time': '2071.05',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2071.05',
#   'stop_time': '2073.11',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2073.11',
#   'stop_time': '2075.206',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2083.51',
#   'stop_time': '2083.76',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2083.76',
#   'stop_time': '2085.52',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2090.04',
#   'stop_time': '2100.44',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2100.44',
#   'stop_time': '2101.536',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2104.52',
#   'stop_time': '2107.63',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2107.63',
#   'stop_time': '2108.224',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2116.8',
#   'stop_time': '2117.15',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2235.62',
#   'stop_time': '2236.81',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2238.384',
#   'stop_time': '2239.679',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2242.08',
#   'stop_time': '2244.624',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2251.02',
#   'stop_time': '2252.68',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2252.68',
#   'stop_time': '2253.9',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2255.03',
#   'stop_time': '2258.98',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2258.98',
#   'stop_time': '2259.89',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2261.58',
#   'stop_time': '2263.873',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2265.6',
#   'stop_time': '2269.68',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2274.04',
#   'stop_time': '2275.08',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2275.08',
#   'stop_time': '2279.083',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2281.32',
#   'stop_time': '2282.05',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2290.32',
#   'stop_time': '2293.9',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2293.9',
#   'stop_time': '2294.6',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2294.6',
#   'stop_time': '2300.28',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2300.28',
#   'stop_time': '2304.31',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2304.31',
#   'stop_time': '2309.24',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2309.24',
#   'stop_time': '2310.44',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2310.44',
#   'stop_time': '2313.37',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2320.96',
#   'stop_time': '2321.99',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2323.34',
#   'stop_time': '2324.07',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2324.07',
#   'stop_time': '2326.448',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2331.35',
#   'stop_time': '2333.47',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2333.47',
#   'stop_time': '2338.77',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2338.77',
#   'stop_time': '2340.69',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2341.008',
#   'stop_time': '2342.0',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2342.02',
#   'stop_time': '2342.96',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2342.96',
#   'stop_time': '2346.26',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2346.26',
#   'stop_time': '2353.45',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2353.45',
#   'stop_time': '2355.94',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2355.94',
#   'stop_time': '2357.15',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2368.848',
#   'stop_time': '2371.92',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2373.56',
#   'stop_time': '2373.71',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2387.12',
#   'stop_time': '2390.64',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2395.86',
#   'stop_time': '2397.04',
#   'participant': 'A',
#   'role': 'Neutral'},
#  {'start_time': '2.41',
#   'stop_time': '5.7',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '5.7',
#   'stop_time': '6.76',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '6.76',
#   'stop_time': '10.67',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '10.67',
#   'stop_time': '18.22',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '18.22',
#   'stop_time': '23.63',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '23.63',
#   'stop_time': '25.04',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '25.04',
#   'stop_time': '30.51',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '31.0',
#   'stop_time': '32.44',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '32.44',
#   'stop_time': '36.3',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '36.3',
#   'stop_time': '42.53',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '42.53',
#   'stop_time': '47.55',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '47.55',
#   'stop_time': '53.09',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '53.09',
#   'stop_time': '54.98',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '54.98',
#   'stop_time': '58.27',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '58.27',
#   'stop_time': '59.8',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '59.8',
#   'stop_time': '61.11',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '61.11',
#   'stop_time': '64.89',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '64.89',
#   'stop_time': '68.34',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '76.93',
#   'stop_time': '77.46',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '79.57',
#   'stop_time': '80.19',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '84.93',
#   'stop_time': '85.28',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '116.08',
#   'stop_time': '118.16',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '136.58',
#   'stop_time': '137.24',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '137.24',
#   'stop_time': '138.22',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '146.11',
#   'stop_time': '147.44',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '147.44',
#   'stop_time': '147.82',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '151.6',
#   'stop_time': '153.45',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '157.49',
#   'stop_time': '158.43',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '162.21',
#   'stop_time': '162.653',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '164.1',
#   'stop_time': '164.75',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '170.93',
#   'stop_time': '171.71',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '176.44',
#   'stop_time': '181.76',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '185.42',
#   'stop_time': '186.12',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '203.12',
#   'stop_time': '204.89',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '205.42',
#   'stop_time': '208.38',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '208.38',
#   'stop_time': '209.09',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '209.09',
#   'stop_time': '211.36',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '211.36',
#   'stop_time': '215.01',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '220.61',
#   'stop_time': '221.12',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '222.23',
#   'stop_time': '222.63',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '222.63',
#   'stop_time': '224.42',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '224.42',
#   'stop_time': '226.35',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '240.91',
#   'stop_time': '241.75',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '241.75',
#   'stop_time': '246.4',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '256.26',
#   'stop_time': '256.62',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '262.0',
#   'stop_time': '262.32',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '264.3',
#   'stop_time': '265.35',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '265.35',
#   'stop_time': '267.02',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '272.68',
#   'stop_time': '273.96',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '277.35',
#   'stop_time': '278.14',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '278.14',
#   'stop_time': '279.61',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '284.28',
#   'stop_time': '289.2',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '289.2',
#   'stop_time': '290.79',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '290.79',
#   'stop_time': '291.49',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '294.34',
#   'stop_time': '295.19',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '308.08',
#   'stop_time': '309.76',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '312.01',
#   'stop_time': '313.57',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '318.84',
#   'stop_time': '320.86',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '320.86',
#   'stop_time': '322.04',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '322.04',
#   'stop_time': '323.23',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '323.23',
#   'stop_time': '324.19',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '330.57',
#   'stop_time': '332.89',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '338.31',
#   'stop_time': '338.66',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '342.18',
#   'stop_time': '343.81',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '343.81',
#   'stop_time': '344.4',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '349.43',
#   'stop_time': '350.21',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '350.21',
#   'stop_time': '351.43',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '354.57',
#   'stop_time': '355.66',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '360.15',
#   'stop_time': '362.85',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '362.85',
#   'stop_time': '364.65',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '378.48',
#   'stop_time': '379.08',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '388.79',
#   'stop_time': '390.11',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '390.11',
#   'stop_time': '391.75',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '393.44',
#   'stop_time': '393.68',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '393.68',
#   'stop_time': '394.67',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '394.67',
#   'stop_time': '397.13',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '397.13',
#   'stop_time': '401.02',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '401.02',
#   'stop_time': '402.02',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '402.02',
#   'stop_time': '404.464',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '405.74',
#   'stop_time': '411.13',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '411.13',
#   'stop_time': '412.35',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '413.89',
#   'stop_time': '417.56',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '417.56',
#   'stop_time': '419.04',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '419.04',
#   'stop_time': '423.2',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '423.2',
#   'stop_time': '424.94',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '424.94',
#   'stop_time': '425.61',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '425.61',
#   'stop_time': '427.19',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '427.19',
#   'stop_time': '427.91',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '431.02',
#   'stop_time': '433.02',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '433.02',
#   'stop_time': '433.93',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '433.93',
#   'stop_time': '435.99',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '435.99',
#   'stop_time': '436.74',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '449.08',
#   'stop_time': '450.0',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '450.0',
#   'stop_time': '452.31',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '456.85',
#   'stop_time': '458.53',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '458.53',
#   'stop_time': '459.05',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '460.87',
#   'stop_time': '463.41',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '464.6',
#   'stop_time': '467.65',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '467.78',
#   'stop_time': '468.92',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '468.92',
#   'stop_time': '471.93',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '471.93',
#   'stop_time': '472.83',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '472.83',
#   'stop_time': '473.82',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '473.82',
#   'stop_time': '475.2',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '479.25',
#   'stop_time': '480.32',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '482.4',
#   'stop_time': '483.16',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '483.16',
#   'stop_time': '486.96',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '490.15',
#   'stop_time': '491.55',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '491.55',
#   'stop_time': '496.28',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '503.04',
#   'stop_time': '503.89',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '503.89',
#   'stop_time': '506.05',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '506.05',
#   'stop_time': '506.51',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '509.59',
#   'stop_time': '509.93',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '512.87',
#   'stop_time': '513.26',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '516.74',
#   'stop_time': '517.32',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '523.59',
#   'stop_time': '524.78',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '524.78',
#   'stop_time': '527.51',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '527.51',
#   'stop_time': '528.69',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '532.53',
#   'stop_time': '534.04',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '534.04',
#   'stop_time': '535.21',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '536.645',
#   'stop_time': '537.22',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '539.58',
#   'stop_time': '540.23',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '540.23',
#   'stop_time': '542.35',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '542.35',
#   'stop_time': '542.93',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '542.93',
#   'stop_time': '543.36',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '543.36',
#   'stop_time': '544.62',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '544.62',
#   'stop_time': '545.54',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '545.54',
#   'stop_time': '549.08',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '549.08',
#   'stop_time': '549.55',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '549.55',
#   'stop_time': '551.27',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '551.27',
#   'stop_time': '555.184',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '560.01',
#   'stop_time': '565.73',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '565.73',
#   'stop_time': '567.05',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '567.05',
#   'stop_time': '567.58',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '567.58',
#   'stop_time': '569.02',
#   'participant': 'B',
#   'role': 'Protagonist'},
#  {'start_time': '569.02',
#   'stop_time': '571.08',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '571.08',
#   'stop_time': '571.48',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '571.48',
#   'stop_time': '571.76',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '571.76',
#   'stop_time': '572.77',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '572.77',
#   'stop_time': '573.77',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '578.66',
#   'stop_time': '579.24',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '580.6',
#   'stop_time': '582.46',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '582.46',
#   'stop_time': '583.02',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '602.97',
#   'stop_time': '603.776',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '605.56',
#   'stop_time': '607.94',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '607.94',
#   'stop_time': '610.56',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '614.74',
#   'stop_time': '617.09',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '617.09',
#   'stop_time': '617.93',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '621.85',
#   'stop_time': '622.38',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '623.387',
#   'stop_time': '626.53',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '626.53',
#   'stop_time': '628.3',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '628.3',
#   'stop_time': '631.48',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '633.87',
#   'stop_time': '634.73',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '637.6',
#   'stop_time': '638.28',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '641.84',
#   'stop_time': '642.35',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '647.71',
#   'stop_time': '652.73',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '652.73',
#   'stop_time': '654.39',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '659.54',
#   'stop_time': '660.12',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '663.86',
#   'stop_time': '664.39',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '664.39',
#   'stop_time': '666.81',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '668.19',
#   'stop_time': '668.78',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '672.26',
#   'stop_time': '673.13',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '679.46',
#   'stop_time': '681.76',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '683.24',
#   'stop_time': '684.307',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '686.65',
#   'stop_time': '687.22',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '687.22',
#   'stop_time': '687.808',
#   'participant': 'B',
#   'role': 'Gatekeeper'},
#  {'start_time': '690.06',
#   'stop_time': '690.74',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '692.44',
#   'stop_time': '692.85',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '701.56',
#   'stop_time': '702.38',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '702.38',
#   'stop_time': '704.23',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '704.23',
#   'stop_time': '707.11',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '707.11',
#   'stop_time': '708.94',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '708.94',
#   'stop_time': '710.26',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '710.26',
#   'stop_time': '711.91',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '711.91',
#   'stop_time': '715.42',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '715.42',
#   'stop_time': '716.384',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '719.99',
#   'stop_time': '721.6',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '724.66',
#   'stop_time': '725.83',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '727.43',
#   'stop_time': '728.12',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '730.58',
#   'stop_time': '733.152',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '735.52',
#   'stop_time': '737.67',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '737.67',
#   'stop_time': '738.92',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '738.92',
#   'stop_time': '741.24',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '741.24',
#   'stop_time': '743.48',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '743.48',
#   'stop_time': '747.01',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '747.01',
#   'stop_time': '748.64',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '748.64',
#   'stop_time': '750.51',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '753.01',
#   'stop_time': '754.67',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '784.01',
#   'stop_time': '785.36',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '785.36',
#   'stop_time': '788.49',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '788.49',
#   'stop_time': '791.85',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '793.04',
#   'stop_time': '793.89',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '793.89',
#   'stop_time': '796.752',
#   'participant': 'B',
#   'role': 'Supporter'},
#  {'start_time': '801.25',
#   'stop_time': '803.8',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '803.8',
#   'stop_time': '805.0',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '805.0',
#   'stop_time': '806.87',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '815.37',
#   'stop_time': '815.87',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '815.87',
#   'stop_time': '816.8',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '816.8',
#   'stop_time': '818.04',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '818.04',
#   'stop_time': '820.49',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '820.49',
#   'stop_time': '821.99',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '821.99',
#   'stop_time': '824.11',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '825.65',
#   'stop_time': '826.99',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '826.99',
#   'stop_time': '828.83',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '830.21',
#   'stop_time': '830.73',
#   'participant': 'B',
#   'role': 'Neutral'},
#  {'start_time': '832.83',
#   'stop_time': '834.78',
#   'participant': 'B',
# ...
#   'stop_time': '605.5',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '612.81',
#   'stop_time': '613.06',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '621.84',
#   'stop_time': '622.14',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '658.82',
#   'stop_time': '659.13',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '663.67',
#   'stop_time': '664.03',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '670.08',
#   'stop_time': '670.72',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '674.83',
#   'stop_time': '674.97',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '674.97',
#   'stop_time': '676.746',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '693.61',
#   'stop_time': '693.78',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '697.36',
#   'stop_time': '697.6',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '700.48',
#   'stop_time': '700.75',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '714.16',
#   'stop_time': '715.024',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '716.26',
#   'stop_time': '719.38',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '721.06',
#   'stop_time': '721.38',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '721.66',
#   'stop_time': '722.38',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '755.56',
#   'stop_time': '761.43',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '762.8',
#   'stop_time': '765.14',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '768.84',
#   'stop_time': '769.1',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '770.55',
#   'stop_time': '770.77',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '770.77',
#   'stop_time': '772.04',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '772.04',
#   'stop_time': '773.49',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '774.2',
#   'stop_time': '776.09',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '776.09',
#   'stop_time': '777.05',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '779.7',
#   'stop_time': '779.95',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '794.83',
#   'stop_time': '795.36',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '807.14',
#   'stop_time': '809.29',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '809.29',
#   'stop_time': '810.03',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '813.554',
#   'stop_time': '814.27',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '815.59',
#   'stop_time': '817.92',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '831.55',
#   'stop_time': '831.81',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '841.48',
#   'stop_time': '841.76',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '845.12',
#   'stop_time': '848.14',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '848.14',
#   'stop_time': '850.06',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '850.06',
#   'stop_time': '856.62',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '856.62',
#   'stop_time': '867.128',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '868.95',
#   'stop_time': '869.4',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '872.38',
#   'stop_time': '873.13',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '875.4',
#   'stop_time': '876.13',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '878.95',
#   'stop_time': '880.14',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '881.32',
#   'stop_time': '882.37',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '882.37',
#   'stop_time': '883.29',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '885.65',
#   'stop_time': '885.99',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '888.03',
#   'stop_time': '888.34',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '889.91',
#   'stop_time': '890.31',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '893.23',
#   'stop_time': '893.51',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '917.01',
#   'stop_time': '917.26',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '923.41',
#   'stop_time': '924.976',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '926.704',
#   'stop_time': '931.04',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '932.5',
#   'stop_time': '932.895',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '935.91',
#   'stop_time': '936.59',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '939.93',
#   'stop_time': '940.49',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '941.3',
#   'stop_time': '941.64',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '942.91',
#   'stop_time': '946.77',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '946.77',
#   'stop_time': '948.68',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '948.68',
#   'stop_time': '951.93',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '951.93',
#   'stop_time': '952.78',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '952.78',
#   'stop_time': '953.8',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '954.878',
#   'stop_time': '955.469',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '956.75',
#   'stop_time': '957.21',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '958.95',
#   'stop_time': '959.77',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '961.8',
#   'stop_time': '962.53',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '962.53',
#   'stop_time': '963.47',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '963.47',
#   'stop_time': '964.01',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '964.9',
#   'stop_time': '965.72',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '970.37',
#   'stop_time': '971.78',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '971.78',
#   'stop_time': '978.496',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '979.64',
#   'stop_time': '980.65',
#   'participant': 'C',
#   'role': None},
#  {'start_time': '980.65',
#   'stop_time': '985.04',
#   'participant': 'C',
#   'role': None},
#  {'start_time': '985.04',
#   'stop_time': '994.01',
#   'participant': 'C',
#   'role': None},
#  {'start_time': '994.01',
#   'stop_time': '996.19',
#   'participant': 'C',
#   'role': None},
#  {'start_time': '996.19',
#   'stop_time': '998.56',
#   'participant': 'C',
#   'role': None},
#  {'start_time': '998.56',
#   'stop_time': '1003.136',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1005.48',
#   'stop_time': '1006.72',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1007.89',
#   'stop_time': '1008.95',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1008.95',
#   'stop_time': '1010.93',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1010.93',
#   'stop_time': '1015.79',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1017.49',
#   'stop_time': '1020.368',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1021.99',
#   'stop_time': '1027.49',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1027.49',
#   'stop_time': '1033.93',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1033.93',
#   'stop_time': '1035.05',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1035.05',
#   'stop_time': '1036.51',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1036.51',
#   'stop_time': '1040.48',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1040.48',
#   'stop_time': '1044.11',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1045.42',
#   'stop_time': '1047.27',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1047.27',
#   'stop_time': '1047.88',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1047.88',
#   'stop_time': '1051.93',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1055.15',
#   'stop_time': '1055.4',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1057.73',
#   'stop_time': '1057.96',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1059.88',
#   'stop_time': '1060.26',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1060.26',
#   'stop_time': '1065.6',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1065.6',
#   'stop_time': '1067.44',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1068.72',
#   'stop_time': '1070.528',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1073.14',
#   'stop_time': '1073.85',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1075.75',
#   'stop_time': '1076.07',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1078.11',
#   'stop_time': '1079.22',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1080.5',
#   'stop_time': '1082.44',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1083.14',
#   'stop_time': '1084.07',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1084.07',
#   'stop_time': '1086.17',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1086.17',
#   'stop_time': '1086.49',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1090.29',
#   'stop_time': '1091.82',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1095.01',
#   'stop_time': '1096.124',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1096.14',
#   'stop_time': '1098.37',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1098.37',
#   'stop_time': '1100.68',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1100.68',
#   'stop_time': '1101.13',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1101.13',
#   'stop_time': '1102.17',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1103.37',
#   'stop_time': '1105.136',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1105.16',
#   'stop_time': '1106.0',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1106.0',
#   'stop_time': '1108.69',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1108.69',
#   'stop_time': '1109.85',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1111.01',
#   'stop_time': '1111.84',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1116.23',
#   'stop_time': '1117.11',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1117.11',
#   'stop_time': '1117.44',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1118.63',
#   'stop_time': '1119.936',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1122.31',
#   'stop_time': '1125.88',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1125.88',
#   'stop_time': '1127.32',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1128.73',
#   'stop_time': '1129.12',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1131.62',
#   'stop_time': '1131.85',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1133.57',
#   'stop_time': '1133.87',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1135.21',
#   'stop_time': '1137.51',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1139.89',
#   'stop_time': '1140.24',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1142.07',
#   'stop_time': '1142.41',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1142.41',
#   'stop_time': '1143.53',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1145.46',
#   'stop_time': '1145.6',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1146.8',
#   'stop_time': '1147.2',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1147.2',
#   'stop_time': '1151.5',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1153.44',
#   'stop_time': '1157.08',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1157.08',
#   'stop_time': '1157.69',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1158.84',
#   'stop_time': '1159.43',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1159.43',
#   'stop_time': '1160.993',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1161.86',
#   'stop_time': '1165.95',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1165.95',
#   'stop_time': '1172.09',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1172.09',
#   'stop_time': '1172.45',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1177.91',
#   'stop_time': '1178.494',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1180.05',
#   'stop_time': '1180.65',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1182.02',
#   'stop_time': '1185.0',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1185.0',
#   'stop_time': '1185.85',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1187.9',
#   'stop_time': '1189.1',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1190.15',
#   'stop_time': '1190.89',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1190.89',
#   'stop_time': '1192.28',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1198.09',
#   'stop_time': '1198.47',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1198.47',
#   'stop_time': '1201.45',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1201.45',
#   'stop_time': '1202.02',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1203.26',
#   'stop_time': '1203.55',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1203.55',
#   'stop_time': '1207.87',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1207.87',
#   'stop_time': '1210.32',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1212.1',
#   'stop_time': '1212.38',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1212.38',
#   'stop_time': '1215.23',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1217.75',
#   'stop_time': '1223.32',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1227.03',
#   'stop_time': '1228.29',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1230.31',
#   'stop_time': '1239.81',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1240.96',
#   'stop_time': '1241.19',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1242.82',
#   'stop_time': '1248.53',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1249.75',
#   'stop_time': '1252.43',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1252.43',
#   'stop_time': '1254.348',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1256.12',
#   'stop_time': '1258.56',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1260.77',
#   'stop_time': '1261.96',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1261.96',
#   'stop_time': '1264.59',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1265.75',
#   'stop_time': '1266.82',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1266.82',
#   'stop_time': '1270.43',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1270.43',
#   'stop_time': '1272.36',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1272.36',
#   'stop_time': '1274.31',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1274.31',
#   'stop_time': '1275.65',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1276.91',
#   'stop_time': '1277.73',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1279.48',
#   'stop_time': '1280.54',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1280.54',
#   'stop_time': '1283.5',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1283.5',
#   'stop_time': '1286.69',
#   'participant': 'C',
#   'role': 'Neutral'},
#  {'start_time': '1286.69',
#   'stop_time': '1293.15',
#   'participant': 'C',
#   'role': 'Neutral'},
#  ...]

# %%
meeting = Meeting(meetings['ES2002d'])
print(meeting.protagonism_prc('B'))
print(meeting.protagonic_participation_time_prc('B'))
# Out:
# 43.71134020618557
# 16.78869238522865

# %%
meetings = []
for meeting in meetings:
    meetings.append()

# %%
for meeting in meetings:
    print("Meeting: ",meeting)
    for p in ["A","B","C","D"]:
        print("Protagonism of", p, ": ", Meeting(meetings[meeting]).protagonism_prc(p))
    print()
    for p in ["A","B","C","D"]:
        print("Protagonistic Time of", p, ": ", Meeting(meetings[meeting]).protagonic_participation_time_prc(p))
    print()
# Out:
# Meeting:  ES2002d
# Protagonism of A :  1.7361111111111112
# Protagonism of B :  43.71134020618557
# Protagonism of C :  0.0
# Protagonism of D :  0.0
#
# Protagonistic Time of A :  0.3571070987551338
# Protagonistic Time of B :  16.78869238522865
# Protagonistic Time of C :  0.0
# Protagonistic Time of D :  0.0
#
# Meeting:  ES2008b
# Protagonism of A :  0.974025974025974
# Protagonism of B :  2.510460251046025
# Protagonism of C :  42.5531914893617
# Protagonism of D :  27.27272727272727
#
# Protagonistic Time of A :  0.4813429153320935
# Protagonistic Time of B :  0.4314616019818347
# Protagonistic Time of C :  12.134250457093197
# Protagonistic Time of D :  10.123445710362528
#
# Meeting:  ES2008d
# Protagonism of A :  9.297520661157025
# Protagonism of B :  0.0
# Protagonism of C :  0.0
# Protagonism of D :  0.0
#
# Protagonistic Time of A :  3.2078218384623693
# Protagonistic Time of B :  0.0
# Protagonistic Time of C :  0.0
# Protagonistic Time of D :  0.0
#
# Meeting:  ES2009d
# Protagonism of A :  11.195928753180661
# Protagonism of B :  0.0
# Protagonism of C :  5.314009661835748
# Protagonism of D :  5.093833780160858
#
# Protagonistic Time of A :  5.616705754151565
# Protagonistic Time of B :  0.0
# Protagonistic Time of C :  2.1997528260382087
# Protagonistic Time of D :  1.9018393304648016
#
# Meeting:  IS1003d
# Protagonism of A :  9.46372239747634
# Protagonism of B :  0.5830903790087464
# Protagonism of C :  4.193548387096775
# Protagonism of D :  15.909090909090908
#
# Protagonistic Time of A :  3.970229674728045
# Protagonistic Time of B :  0.23253583928657157
# Protagonistic Time of C :  1.863566834107803
# Protagonistic Time of D :  5.165805142018344

# %%
for meeting_id in meeting_ids:
    print('Meeting ID: ',meeting_id)
    print()
    pt = sum(Meeting(meetings[meeting_id]).participation_time('A'))
    pt += sum(Meeting(meetings[meeting_id]).participation_time('B'))
    pt += sum(Meeting(meetings[meeting_id]).participation_time('C'))
    pt += sum(Meeting(meetings[meeting_id]).participation_time('D'))

    ct = float(meetings[meeting_id][-1]['endtime'])*4
    st = ct - pt
    print('Silence total time: ',st)
    print('Silence total prc: ',st/ct)
    print()
# Out:
# Meeting ID:  ES2002d
#
# Silence total time:  6861.495000000008
# Silence total prc:  0.7289350730476029
#
# Meeting ID:  ES2008b
#
# Silence total time:  6973.494999999999
# Silence total prc:  0.7823046564745052
#
# Meeting ID:  ES2008d
#
# Silence total time:  7867.3859999999995
# Silence total prc:  0.7524566739354986
#
# Meeting ID:  ES2009d
#
# Silence total time:  5963.491000000003
# Silence total prc:  0.7049377039103507
#
# Meeting ID:  IS1003d
#
# Silence total time:  5514.331000000001
# Silence total prc:  0.6678629909358242
