# %%
import csv 

with open('SocialRoleAnnotation/scenario/ES2002d.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
         print(', '.join(row))
# Out:
# ES2002d,ES2002d_179_212,179,212,A,Supporter
# ES2002d,ES2002d_179_212,179,212,B,Gatekeeper
# ES2002d,ES2002d_179_212,179,212,C,Supporter
# ES2002d,ES2002d_179_212,179,212,D,Supporter
# ES2002d,ES2002d_158_179,158,179,A,Protagonist
# ES2002d,ES2002d_158_179,158,179,B,Supporter
# ES2002d,ES2002d_158_179,158,179,C,Supporter
# ES2002d,ES2002d_158_179,158,179,D,Neutral
# ES2002d,ES2002d_498_533,498,533,A,Supporter
# ES2002d,ES2002d_498_533,498,533,B,Gatekeeper
# ES2002d,ES2002d_498_533,498,533,C,Neutral
# ES2002d,ES2002d_498_533,498,533,D,Supporter
# ES2002d,ES2002d_979_1001,979,1001,A,Neutral
# ES2002d,ES2002d_979_1001,979,1001,B,Neutral
# ES2002d,ES2002d_979_1001,979,1001,C,Protagonist
# ES2002d,ES2002d_979_1001,979,1001,D,Neutral
# ES2002d,ES2002d_330_374,330,374,A,Supporter
# ES2002d,ES2002d_330_374,330,374,B,Gatekeeper
# ES2002d,ES2002d_330_374,330,374,C,Supporter
# ES2002d,ES2002d_330_374,330,374,D,Supporter
# ES2002d,ES2002d_2145_2195,2145,2195,A,Neutral
# ...
